# %% [markdown]
# ## Plotting live data in real time

# %%
# %matplotlib notebook
import random
from itertools import count
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# %%
x_val=[]
y_val=[]

index=count()
print(next(index))

def animate(i):
    x_val.append(next(index))
    y_val.append(random.randint(0,5))
    plt.plot(x_val,y_val)

ani = FuncAnimation(plt.gcf(),animate, interval=1000)  # interval=1000 means matplotlib is going to run this animate 
#function every second
plt.show()
# Out:
# 0
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Each time there will be a different color because our plot method is actually plotting a brand new line every time but it's not clearing out the old lines. So, there are actually multiple lines getting stacked on top of each other. The one way we can solve this is simply clear out our axis. If we do that everytime it plots the new line from the scratch. To clear the line we can simply use the cla method. Which means clear axis.

# %%
x_val=[]
y_val=[]

index=count()
print(next(index))

def animate(i):
    x_val.append(next(index))
    y_val.append(random.randint(0,5))
    plt.cla()
    plt.plot(x_val,y_val)

ani = FuncAnimation(plt.gcf(),animate, interval=1000)  # interval=1000 means matplotlib is going to run this animate 
#function every second
plt.show()
# Out:
# 0
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Let's plot data from a csv
# This csv is constantly updated by an outside source like from online api or sensor

# %%
x_val=[]
y_val=[]

index=count()
print(next(index))

def animate(i):
    data = pd.read_csv("realdata.csv")
    x = data['x_value']
    y1= data['total_1']
    y2= data['total_2']
    
    plt.cla()
    plt.plot(x,y1,label = 'channel1')
    plt.plot(x,y2,label = 'channel2')
    
    plt.legend(loc='upper left')

ani = FuncAnimation(plt.gcf(),animate, interval=1000)  # interval=1000 means matplotlib is going to run this animate 
#function every second
plt.show()
# Out:
# 0
# <img src="data:image/png;base64,..." width="640">
