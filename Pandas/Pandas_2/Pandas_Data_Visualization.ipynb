# %% [markdown]
# # Data Visualization

# %%
import pandas as pd

ratings = pd.read_csv('movielens/ratings.csv')

# %%
ratings.isnull().any()
# Out:
# userId       False
# movieId      False
# rating        True
# timestamp    False
# dtype: bool

# %%
ratings = ratings.fillna(ratings['rating'].mean())

# %%
ratings.isnull().any()
# Out:
# userId       False
# movieId      False
# rating       False
# timestamp    False
# dtype: bool

# %%
# %matplotlib inline

ratings.plot('userId','rating', figsize = (15,10))

# %%
ratings1 = pd.read_csv('./movielens/ratings1.csv')

ratings1 = ratings1.fillna(ratings1['rating'].mean())
ratings1
# Out:
#     userId  movieId    rating  timestamp
# 0        1        1  4.277778  964982703
# 1        2        3  4.000000  964981247
# 2        3        6  4.000000  964982224
# 3        4       47  4.277778  964983815
# 4        5       50  5.000000  964982931
# 5        6       70  3.000000  964982400
# 6        7      101  5.000000  964980868
# 7        8      110  4.000000  964982176
# 8        9      151  5.000000  964984041
# 9       10      157  5.000000  964984100
# 10      11      163  5.000000  964983650
# 11      12      216  5.000000  964981208
# 12      13      223  3.000000  964980985
# 13      14      231  5.000000  964981179
# 14      15      235  4.000000  964980908
# 15      16      260  5.000000  964981680
# 16      17      296  3.000000  964982967
# 17      18      316  3.000000  964982310
# 18      19      333  5.000000  964981179
# 19      20      349  4.000000  964982563

# %%
ratings1.plot('movieId','rating',figsize = (15,10))

# %%
ratings1.plot(figsize = (15,10))

# %%
ratings.plot.hist(figsize = (15,10))

# %%
ratings.hist(figsize = (15,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f09362dad90>,
# ...
#       dtype=object)

# %%
ratings.hist(column = 'rating', figsize = (15,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0935f3f890>]],
#       dtype=object)

# %%
ratings1 = pd.read_csv('./movielens/ratings1.csv')

del ratings1['timestamp']

# %%
ratings1['movieId'] = ratings['movieId']/10

# %%
ratings1.plot.bar(figsize = (15,10))

# %%
ratings.boxplot(column = 'rating',figsize = (10,7))

# %%
ratings.boxplot(column = 'movieId',figsize = (10,7))

# %%
ratings.boxplot(figsize = (10,7))
